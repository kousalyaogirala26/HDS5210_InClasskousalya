# %% [markdown]
# <a href="https://colab.research.google.com/github/kousalyaogirala26/HDS5210_InClasskousalya/blob/master/Copy_of_week12_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 12 Assignment
#
# # PART 1 - Pivoting Data for Fun!
#
# In this exercise, we're going to work with data about condemned buildings in St. Louis.  This data set is in `/data/condemn.txt` in CSV format.

# %% [markdown]
# ## STEP 1: Load and Filter data
#
# For this analysis, we want to look only at a relevent range of years and only years that are in teh past.  So, let's first take a look at the data between 1986 and 2014 (inclusive of those dates).
#
# At the end of this step, you should have a data frame loaded from the condemnations file and filtered down to only the data between 1986 and 2014.  Put that into a dataframe named `condemnations`
#
# **Some helpful notes:**
# * Use the columns `InspectDate` to filter this date range

# %%
# %matplotlib inline
import pandas as pd

condemnations = pd.read_csv('condemn.txt')
condemnations.shape
# Out:
# <ipython-input-3-4427bda89e9a>:4: DtypeWarning: Columns (2,8,35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   condemnations = pd.read_csv('condemn.txt')
# (32586, 40)

# %%
# The first time i have run the file it gave me a warning about one of the columns having mixed data types
# and that I should consider manually specifying the data type or setting low_memory=False
# So, I set low_memory=False

# %%
condemnations['InspectDate'] = pd.to_datetime(condemnations['InspectDate'])
condemnations = condemnations[(condemnations['InspectDate'].dt.year >= 1986) & (condemnations['InspectDate'].dt.year <= 2014)]

# %%
assert(condemnations.shape == (30232, 40))
assert(len(condemnations[condemnations['InspectDate'] < '1986'])==0)
assert(len(condemnations[condemnations['InspectDate'] >= '2015'])==0)

# %% [markdown]
# ## STEP 2: Pivot and Summarize
#
# In this step we want to pivot our data so that we have one row per year, a column for each value that appears in the `Status` column, and a count of how many condemnations occurred of each type in each year.  Put your summary pivot table into a variable called `by_year`.
#
# **Some helpful notes:**
# * For some reason, Pandas is just kind of stubborn about count being the aggregate function.  You may need to tell it to `np.ma.count` specifically.  I've imported Numpy as np for you.

# %%
import numpy as np
###creating a pivot tabel..
###first we need to create a year column
condemnations['Year'] = condemnations['InspectDate'].dt.year

### Then Creat Pivot tabel
by_year = condemnations.pivot_table (
    values='AcctNum',
    index=condemnations['InspectDate'].dt.year,
    columns='Status',
    aggfunc=np.ma.count,
    fill_value=0
)
# checking out the data frame by year.
by_year
# Out:
# Status          B    L   R    W
# InspectDate
# 1986           22   12  19  112
# 1987           91   20   8  361
# 1988          215   16  15  297
# 1989          277   15  11  432
# 1990          119   29   8  322
# 1991          139   18   4  351
# 1992          204   30   4  258
# 1993          185   47   2  193
# 1994          208   94   5  293
# 1995          176  127   0  268
# 1996          214  171   0  794
# 1997          281  328   0  878
# 1998          254  343   0  599
# 1999          272  283   0  826
# 2000          320  268   0  529
# 2001          381  262   0  296
# 2002          383  227   0  317
# 2003          361  201   0  282
# 2004          354  204   0  381
# 2005          410  237   0  345
# 2006          479  233  20  370
# 2007          613  262   0  341
# 2008          700  254   0  334
# 2009          785  223   0  200
# 2010         1161  193   0  154
# 2011         1028  275   0  107
# 2012          738  257   1   28
# 2013          185  209   1    2
# ...

# %%
assert(by_year.shape == (29, 4))
assert(list(by_year.columns) == ['B', 'L', 'R', 'W'])
assert(list(by_year.sum()) == [10572, 4966, 98, 9670])

# %% [markdown]
# ## STEP 3: Plot and see what you see
#
# Use Pandas built-in plotting capabilities to visualize this information in way that you think makes sense.  It might be that plotting a simple multi-series line chart would give you some insights.  Show your plot in the cell below, then use the text cell below that to write a few sentences about what you see.

# %%
# %matplotlib inline
by_year.plot()
# Out:
# <Axes: xlabel='InspectDate'>

# %% [markdown]
# ---

# %%
# Import the necessary library
import matplotlib.pyplot as plt

# Plotting a stacked horizontal bar plot
by_year.plot(kind='barh', figsize=(12, 8), title="Condemnations by Year and Status", stacked=True)

# Add labels and legend
plt.xlabel("Count of Condemnations") # Now plt is defined and can be used
plt.ylabel("Year")
plt.legend(title="Status", loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# The red category ("W") seems to dominate the total condemnations for many years, especially from the late 1980s to early 2000s.
#
# From 2010 onward, the number of condemnations decreases significantly, with blue ("B") and orange ("L") categories becoming more prominent.
#
# There’s a notable increase in condemnations in the mid-2000s, particularly in the blue and orange categories.
#
# In the late 1980s and early 1990s, the red category is overwhelmingly prevalent, with minimal representation from other categories.

# %% [markdown]
# # PART 2 - Video Conference Usage
#
# In this next part of the assignment, we'll be looking at how video conference usage changed during the beginning of COVID-19.  This real data.  Please don't judge anyone based on the information here.  ;)  The data is in the `/data/meetings.csv` file.
#
# For the assignment, I want you to compare (by person) the number of meetings hosted by each user for the last two weeks of February and the last two weeks of March.  This might be a little complicated to think through HOW to do that, so the steps below are one approach.
#
# 1. Create a new column called startDate that contains just the day part of the startTime column in the data.  You can do that using datetime functions if you want, but you'll notice that the date in this file is a string formatted YYYY-MM-DD-HH:mm:ss, so it's probably easier just to pull out the first 10 characters of the string instead.  `meetings['startTime'].str[0:10]`
# 2. Create another new column.  This one should contain a label like "BEFORE" for the week 2/17 - 2/28 and "DURING" for the week of 3/16 - 3/27.  A hand tip on this is that you can set values for some rows in a data frame using `meetings.loc[row_filter,'Column Name'] = 'Value'` if you've created a `row_filter` as we discussed in prior weeks.
# 3. From here, using `pivot_table()` is one good way to summarize the information.
#
# **FINAL RESULT**
#
# For a final result, I'd like you to produce a data frame named **summary** that contains:
# * One ROW for each userName.  The userName can either be the row index or a column in the data frame.
# * One COLUMN for the "BEFORE" week and one COLUMN for the "DURING" week.  Name those columns 'Before' and 'During'.
# * One more calculated column that shows the percent increase from BEFORE to DURING.  Name that column 'pctChange'.

# %%
import pandas as pd
meetings = pd.read_csv('meetings.csv')

# %%
###checking the data
meetings.head()
# Out:
#                                   meeting_uuid                   meetingTitle  \
# 0  418897-3b9f0feb-f8f4-4ae7-9464-eb983c30af60          Review Payer Websites
# 1  418897-14587f14-faf0-4879-9756-fe335357b413                 Drew's Meeting
# 2  418897-aa82b3f0-e3df-456a-80d5-daef7902c232  St. Luke's Project Discussion
# 3  418867-f5fadea7-75f8-4860-9a1e-090805ff6346                 Amit's Meeting
# 4  418894-3a911019-1a97-4058-8bd4-035245c73bda               Andrea's Meeting
#
#    meetingId                        userName  user_id  user_tags  \
# 0  681568231   chris.rogers.amitechsolutions  3180644        NaN
# 1  258719784                      Drew.Marco  2717893        NaN
# 2  415828450                     eric.keeney  2692908        NaN
# 3  275007771                     amit.bhagat  2756615        NaN
# 4  791412043  andrea.bryant.amitechsolutions  2673353        NaN
#
#                endTime            startTime  \
# 0  2020-03-31 22:21:35  2020-03-31 21:00:22
# ...

# %%
meetings.shape
# Out:
# (1188, 25)

# %%
###creating start date column
meetings['startDate'] = meetings['startTime'].str[0:10]

### Creating before and during filters
before_filter = (meetings['startDate'] >= '2020-02-17') & (meetings['startDate'] <= '2020-02-28')
during_filter = (meetings['startDate'] >= '2020-03-16') & (meetings['startDate'] <= '2020-03-27')

### Creating the Time Frame column with our "BEFORE" or "DURING" value
meetings.loc[before_filter, 'timeFrame'] = 'Before'
meetings.loc[during_filter, 'timeFrame'] = 'During'

# %%
### checking the new column
meetings['timeFrame'].value_counts()
# Out:
# timeFrame
# During    278
# Before    179
# Name: count, dtype: int64

# %%
# creating the pivot tabel so each timeFrame value becomes a separate column and we only have one row per user
summary = meetings.pivot_table(
    index='userName',
    columns='timeFrame',
    values='meeting_uuid',
    aggfunc='count',
    fill_value=0
)

# %%
###checking the input
summary.head()
# Out:
# timeFrame                       Before  During
# userName
# Drew.Marco                          12      19
# amit.bhagat                         17      30
# andrea.bryant.amitechsolutions       5       3
# angie.warren                         5       9
# chris.rogers.amitechsolutions        4       3

# %%
# calculating a difference and percent change
summary["pctChange"] = (summary["During"] - summary["Before"]) / summary["Before"]

# %%
###checking input
summary
# Out:
# timeFrame                       Before  During  pctChange
# userName
# Drew.Marco                          12      19   0.583333
# amit.bhagat                         17      30   0.764706
# andrea.bryant.amitechsolutions       5       3  -0.400000
# angie.warren                         5       9   0.800000
# chris.rogers.amitechsolutions        4       3  -0.250000
# eric.keeney                         15      27   0.800000
# eric.rodman                          4      12   2.000000
# jeff.hatfield.amitechsolutions      13      26   1.000000
# jennifer.patton.amitechs             5       7   0.400000
# jessica.sikora                       3       7   1.333333
# matt.allsup                          5       0  -1.000000
# matt.brown.amitechsolutions          1       2   1.000000
# melissa.menne                       10       9  -0.100000
# michael.demos                        5      11   1.200000
# paul.boal                           15      35   1.333333
# ...

# %% [markdown]
# ---

# %%
assert(len(summary) == 22)

# %%
assert(summary['pctChange'].mean().round(2) == 0.92)

# %% [markdown]
# ---
#
#
#
# ## Submitting Your Work
#
# Submit as usual
